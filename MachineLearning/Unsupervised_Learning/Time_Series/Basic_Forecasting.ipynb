# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('product_sales.csv')

# %%
data
# Out:
#     Products_sold_milllions
# 0                        15
# 1                        20
# 2                        16
# 3                        13
# 4                        18
# 5                        14
# 6                        15
# 7                        17
# 8                        20
# 9                        20
# 10                       18
# 11                       20
# 12                       10
# 13                       17
# 14                       17
# 15                       18
# 16                       18
# 17                       14
# 18                       14
# 19                       14
# 20                       19
# 21                       12
# 22                       13
# 23                       14

# %%
data.index = data.index +1

# %%
data
# Out:
#     Products_sold_milllions
# 1                        15
# 2                        20
# 3                        16
# 4                        13
# 5                        18
# 6                        14
# 7                        15
# 8                        17
# 9                        20
# 10                       20
# 11                       18
# 12                       20
# 13                       10
# 14                       17
# 15                       17
# 16                       18
# 17                       18
# 18                       14
# 19                       14
# 20                       14
# 21                       19
# 22                       12
# 23                       13
# 24                       14

# %% [markdown]
# # Naive technique

# %%
naive = data.copy()

# %%
naive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 1 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Products_sold_milllions  24 non-null     int64
# dtypes: int64(1)
# memory usage: 324.0 bytes

# %%
naive['Products_sold_milllions'] = naive['Products_sold_milllions'].shift(1)

# %%
naive
# Out:
#     Products_sold_milllions
# 1                       NaN
# 2                      15.0
# 3                      20.0
# 4                      16.0
# 5                      13.0
# 6                      18.0
# 7                      14.0
# 8                      15.0
# 9                      17.0
# 10                     20.0
# 11                     20.0
# 12                     18.0
# 13                     20.0
# 14                     10.0
# 15                     17.0
# 16                     17.0
# 17                     18.0
# 18                     18.0
# 19                     14.0
# 20                     14.0
# 21                     14.0
# 22                     19.0
# 23                     12.0
# 24                     13.0

# %%
plt.plot(data.index, data['Products_sold_milllions'], label='actuals')
plt.plot(naive.index, naive['Products_sold_milllions'], label='naive')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae_naive = mean_absolute_error( data.loc[2:,'Products_sold_milllions'],  naive.loc[2:,'Products_sold_milllions'])
print(mae_naive)
# Out:
# 2.9130434782608696

# %% [markdown]
# # SMA
#
# * LAG = 1

# %%
sma1=data.rolling(window=2).mean()

# %%
sma1
# Out:
#     Products_sold_milllions
# 1                       NaN
# 2                      17.5
# 3                      18.0
# 4                      14.5
# 5                      15.5
# 6                      16.0
# 7                      14.5
# 8                      16.0
# 9                      18.5
# 10                     20.0
# 11                     19.0
# 12                     19.0
# 13                     15.0
# 14                     13.5
# 15                     17.0
# 16                     17.5
# 17                     18.0
# 18                     16.0
# 19                     14.0
# 20                     14.0
# 21                     16.5
# 22                     15.5
# 23                     12.5
# 24                     13.5

# %%
plt.figure(figsize=(12,6))
plt.plot(data.index, data['Products_sold_milllions'], label='actuals')
plt.plot(sma1.index, sma1['Products_sold_milllions'], label='SMA-lag-1')
plt.legend()
plt.show()

# %%
mae_sma = mean_absolute_error( data.loc[2:,'Products_sold_milllions'],  sma1.loc[2:,'Products_sold_milllions'])
print(mae_sma)
# Out:
# 1.4565217391304348

# %% [markdown]
# * LAG = 2

# %%
sma2=data.rolling(window=3).mean()

# %%
sma2
# Out:
#     Products_sold_milllions
# 1                       NaN
# 2                       NaN
# 3                 17.000000
# 4                 16.333333
# 5                 15.666667
# 6                 15.000000
# 7                 15.666667
# 8                 15.333333
# 9                 17.333333
# 10                19.000000
# 11                19.333333
# 12                19.333333
# 13                16.000000
# 14                15.666667
# 15                14.666667
# 16                17.333333
# 17                17.666667
# 18                16.666667
# 19                15.333333
# 20                14.000000
# 21                15.666667
# 22                15.000000
# 23                14.666667
# 24                13.000000

# %%
plt.figure(figsize=(12,6))
plt.plot(data.index, data['Products_sold_milllions'], label='actuals')
plt.plot(sma2.index, sma2['Products_sold_milllions'], label='SMA-lag-2')
plt.legend()
plt.show()

# %%
mae_sma2 = mean_absolute_error( data.loc[3:,'Products_sold_milllions'],  sma2.loc[3:,'Products_sold_milllions'])
print(mae_sma2)
# Out:
# 1.787878787878788

# %% [markdown]
# # MAE
#
# * Naive = 2.91
#
# * SMA lag1 = 1.45
#
# * SMA_lag2 = 1.78
#
# ## SMA with lag1 is forecasting better than the other basic techniques

# %%
plt.plot(data.index, data['Products_sold_milllions'], label='actuals')
plt.plot(naive.index, naive['Products_sold_milllions'], label='naive')
plt.plot(sma1.index, sma1['Products_sold_milllions'], label='sma lag=1')
plt.plot(sma2.index, sma2['Products_sold_milllions'], label='sma lag=2')
plt.legend()
plt.show()
