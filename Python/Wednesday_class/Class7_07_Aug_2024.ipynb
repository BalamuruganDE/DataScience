# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/bkannadasan/Documents/GitHub/DataScience/Python/Wednesday_class'

# %%
df = pd.read_csv('Dataset/amusementpark_rider.csv')

# %%
df.shape
# Out:
# (1088, 56)

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
pd.set_option('display.max_columns',100)

# %%
df[:2]
# Out:
#          coaster_name          Length             Speed       Location  \
# 0  Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)   Coney Island
# 1   Flip Flap Railway             NaN               NaN  Sea Lion Park
#
#     Status   Opening date  Type            Manufacturer Height restriction  \
# 0  Removed  June 16, 1884  Wood  LaMarcus Adna Thompson                NaN
# 1  Removed           1895  Wood            Lina Beecher                NaN
#
#          Model        Height  Inversions Lift/launch system Cost  \
# 0  Lift Packed  50 ft (15 m)         NaN            gravity  NaN
# 1          NaN           NaN         1.0                NaN  NaN
#
#                                               Trains  \
# 0                                                NaN
# 1  a single car. Riders are arranged 1 across in ...
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site    01:00  1600 riders per hour     2.9
# ...

# %%
df.tail()
# Out:
#                         coaster_name                Length  \
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
# 1087  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
# 1087         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1083           2022                      Steel – Launched
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
# To see stats about the 
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  933.000000      1088.000000  812.000000  812.000000    938.000000
# mean     1.548767      1995.011029   38.373484  -41.595373     53.854797
# std      2.113474        23.478736   15.516596   72.285227     23.373429
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  938.000000    966.000000  171.000000       1088.000000    362.000000
# mean    48.627292     89.618054  101.996491          1.328125      3.824006
# std     16.671944    136.182354   67.329092          2.030553      0.989998
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1088 entries, 0 to 1087
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1088 non-null   object
#  1   Length                         954 non-null    object
#  2   Speed                          938 non-null    object
#  3   Location                       1088 non-null   object
#  4   Status                         875 non-null    object
#  5   Opening date                   838 non-null    object
#  6   Type                           1088 non-null   object
#  7   Manufacturer                   1029 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          745 non-null    object
#  10  Height                         966 non-null    object
#  11  Inversions                     933 non-null    float64
# ...

# %%
# Show column data-types of all columns
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.dtypes('float')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.dtypes('float')
#
# TypeError: 'Series' object is not callable

# %%
#Include specific data-types
df.select_dtypes(include='float64').columns
# Out:
# Index(['Inversions', 'latitude', 'longitude', 'speed1_value', 'speed_mph',
#        'height_value', 'height_ft', 'Gforce_clean'],
#       dtype='object')

# %%
#Exclude specific data-types
df.select_dtypes(exclude='float64').columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Lift/launch system', 'Cost', 'Trains', 'Park section', 'Duration',
#        'Capacity', 'G-force', 'Designer', 'Max vertical angle', 'Drop',
#        'Soft opening date', 'Fast Lane available', 'Replaced', 'Track layout',
#        'Fastrack available', 'Soft opening date.1', 'Closing date', 'Opened',
#        'Replaced by', 'Website', 'Flash Pass Available',
#        'Must transfer from wheelchair', 'Theme', 'Single rider line available',
#        'Restraint Style', 'Flash Pass available', 'Acceleration', 'Restraints',
#        'Name', 'year_introduced', 'Type_Main', 'opening_date_clean', 'speed1',
#        'speed2', 'speed1_unit', 'height_unit', 'Inversions_clean'],
#       dtype='object')

# %%
df
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
# 1087          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
#To drop specific column
df1=df.drop(['Opening date'],axis=1)

# %%
df1.shape
# Out:
# (1088, 55)

# %%
df.loc[['Opening date','Length']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.loc[['Opening date','Length']]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
#    1380         raise ValueError("Cannot index with multidimensional key")
# -> 1382     return self._getitem_iterable(key, axis=axis)
#    1384 # nested tuple slicing
#    1385 if is_nested_tuple(key, labels):
#
# ...

# %%
# TO choose specific columns
df[['coaster_name','Length','Manufacturer']]
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
# 1087          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                      Manufacturer
# 0          LaMarcus Adna Thompson
# 1                    Lina Beecher
# 2                             NaN
# ...

# %%
df.shape
# Out:
# (1088, 56)

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.coaster_name # Can be used to call only single column , also this will not support if the coulmn name has space and if we want to read multiple columns
# Out:
# 0                           Switchback Railway
# 1                            Flip Flap Railway
# 2       Switchback Railway (Euclid Beach Park)
# 3                 Loop the Loop (Coney Island)
# 4                 Loop the Loop (Young's Pier)
#                          ...
# 1083                 Pantheon (roller coaster)
# 1084                 Tron Lightcycle Power Run
# 1085                                   Tumbili
# 1086            Wonder Woman Flight of Courage
# 1087            Wonder Woman Flight of Courage
# Name: coaster_name, Length: 1088, dtype: object

# %%
df['coaster_name'] # One column read and in pandas single column is consider as series
# Out:
# 0                           Switchback Railway
# 1                            Flip Flap Railway
# 2       Switchback Railway (Euclid Beach Park)
# 3                 Loop the Loop (Coney Island)
# 4                 Loop the Loop (Young's Pier)
#                          ...
# 1083                 Pantheon (roller coaster)
# 1084                 Tron Lightcycle Power Run
# 1085                                   Tumbili
# 1086            Wonder Woman Flight of Courage
# 1087            Wonder Woman Flight of Courage
# Name: coaster_name, Length: 1088, dtype: object

# %%
type(df['coaster_name'])
# Out:
# pandas.core.series.Series

# %%
df[['coaster_name','Length']]
# Out:
#                                 coaster_name                Length
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
# 1087          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
# [1088 rows x 2 columns]

# %%
type(df[['coaster_name','Length']] ) # when multiple columns are read it is considered as dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df.opening_date_clean
# Out:
# 0       1884-06-16
# 1       1895-01-01
# 2              NaN
# 3       1901-01-01
# 4       1901-01-01
#            ...
# 1083    2022-01-01
# 1084    2016-06-16
# 1085           NaN
# 1086    2022-01-01
# 1087    2022-01-01
# Name: opening_date_clean, Length: 1088, dtype: object

# %%
df['opening_date_clean']+20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %%
df['opening_date_clean']+"20"
# Out:
# 0       1884-06-1620
# 1       1895-01-0120
# 2                NaN
# 3       1901-01-0120
# 4       1901-01-0120
#             ...
# 1083    2022-01-0120
# 1084    2016-06-1620
# 1085             NaN
# 1086    2022-01-0120
# 1087    2022-01-0120
# Name: opening_date_clean, Length: 1088, dtype: object

# %%
df['opening_date_clean'].astype('date64[pyarrow]')
# Out:
# 0       1884-06-16
# 1       1895-01-01
# 2             <NA>
# 3       1901-01-01
# 4       1901-01-01
#            ...
# 1083    2022-01-01
# 1084    2016-06-16
# 1085          <NA>
# 1086    2022-01-01
# 1087    2022-01-01
# Name: opening_date_clean, Length: 1088, dtype: date64[ms][pyarrow]

# %%
df['opening_date_clean']=pd.to_datetime(df['opening_date_clean'])

# %%
df['opening_date_clean'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df.select_dtypes(exclude='object')
# Out:
#       Inversions  year_introduced  latitude  longitude opening_date_clean  \
# 0            NaN             1884   40.5740   -73.9780         1884-06-16
# 1            1.0             1895   40.5780   -73.9790         1895-01-01
# 2            NaN             1896   41.5800   -81.5700                NaT
# 3            1.0             1901   40.5745   -73.9780         1901-01-01
# 4            1.0             1901   39.3538   -74.4342         1901-01-01
# ...          ...              ...       ...        ...                ...
# 1083         2.0             2022   37.2339   -76.6426         2022-01-01
# 1084         0.0             2022       NaN        NaN         2016-06-16
# 1085         0.0             2022       NaN        NaN                NaT
# 1086         3.0             2022       NaN        NaN         2022-01-01
# 1087         3.0             2022       NaN        NaN         2022-01-01
#
#       speed1_value  speed_mph  height_value  height_ft  Inversions_clean  \
# ...

# %%
df1=df[['opening_date_clean','latitude']]

# %%
df1.dtypes
# Out:
# opening_date_clean    datetime64[ns]
# latitude                     float64
# dtype: object

# %%
import datetime

# %%
df1.head()
# Out:
#   opening_date_clean  latitude
# 0         1884-06-16   40.5740
# 1         1895-01-01   40.5780
# 2                NaT   41.5800
# 3         1901-01-01   40.5745
# 4         1901-01-01   39.3538

# %%
df1.dtypes
# Out:
# opening_date_clean    datetime64[ns]
# latitude                     float64
# dtype: object

# %%
pd.DataFrame(df1['opening_date_clean'],df1['opening_date_clean']+datetime.timedelta(days=1))
# Out:
#                    opening_date_clean
# opening_date_clean
# 1884-06-17                        NaT
# 1895-01-02                        NaT
# NaT                               NaT
# 1901-01-02                        NaT
# 1901-01-02                        NaT
# ...                               ...
# 2022-01-02                        NaT
# 2016-06-17                        NaT
# NaT                               NaT
# 2022-01-02                        NaT
# 2022-01-02                        NaT
#
# [1088 rows x 1 columns]

# %%
df1['opening_date_clean'].min()
# Out:
# Timestamp('1884-06-16 00:00:00')

# %%
df1['opening_date_clean'].max()
# Out:
# Timestamp('2022-03-01 00:00:00')

# %%
df1.columns
# Out:
# Index(['opening_date_clean', 'latitude'], dtype='object')

# %%
df1.rename([['opening_date_clean'],['Opening_Date_Clean']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 df1.rename([['opening_date_clean'],['Opening_Date_Clean']])
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5518, in DataFrame.rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5399 def rename(
#    5400     self,
#    5401     mapper: Renamer | None = None,
#    (...)
#    5409     errors: IgnoreRaise = "ignore",
#    5410 ) -> DataFrame | None:
#    5411     """
#    5412     Rename columns or index labels.
#    5413
#    (...)
#    5516     4  3  6
#    5517     """
# -> 5518     return super()._rename(
#    5519         mapper=mapper,
#    5520         index=index,
#    5521         columns=columns,
#    5522         axis=axis,
#    5523         copy=copy,
#    5524         inplace=inplace,
#    5525         level=level,
# ...

# %%
df1.rename?
# Out:
# Signature:
# df1.rename(
#     mapper: 'Renamer | None' = None,
#     *,
#     index: 'Renamer | None' = None,
#     columns: 'Renamer | None' = None,
#     axis: 'Axis | None' = None,
#     copy: 'bool | None' = None,
#     inplace: 'bool' = False,
#     level: 'Level | None' = None,
#     errors: 'IgnoreRaise' = 'ignore',
# ) -> 'DataFrame | None'
# Docstring:
# Rename columns or index labels.
#
# Function / dict values must be unique (1-to-1). Labels not contained in
# a dict / Series will be left as-is. Extra labels listed don't throw an
# error.
#
# See the :ref:`user guide <basics.rename>` for more.
#
# Parameters
# ----------
# mapper : dict-like or function
#     Dict-like or function transformations to apply to
#     that axis' values. Use either ``mapper`` and ``axis`` to
#     specify the axis to target with ``mapper``, or ``index`` and
#     ``columns``.
# index : dict-like or function
#     Alternative to specifying axis (``mapper, axis=0``
# ...

# %%
df1.rename(columns='opening_date_clean':'Opening_Date_Clean')
# Out:
#   Cell In[116], line 1
#     df1.rename(columns='opening_date_clean':'Opening_Date_Clean')
#                                            ^
# SyntaxError: invalid syntax

# %%
#Rename columns
df1.rename(columns={'opening_date_clean':'Opening_Date_Clean','latitude':'Latitude'})
# Out:
#      Opening_Date_Clean  Latitude
# 0            1884-06-16   40.5740
# 1            1895-01-01   40.5780
# 2                   NaT   41.5800
# 3            1901-01-01   40.5745
# 4            1901-01-01   39.3538
# ...                 ...       ...
# 1083         2022-01-01   37.2339
# 1084         2016-06-16       NaN
# 1085                NaT       NaN
# 1086         2022-01-01       NaN
# 1087         2022-01-01       NaN
#
# [1088 rows x 2 columns]

# %%
df1.duplicated().sum()
# Out:
# 285

# %%
df[df.duplicated()] # Finds and prints duplicate record
# Out:
#                         coaster_name              Length             Speed  \
# 1087  Wonder Woman Flight of Courage  3,300 ft (1,000 m)  58 mph (93 km/h)
#
#                       Location              Status Opening date  \
# 1087  Six Flags Magic Mountain  Under construction         2022
#
#                      Type                 Manufacturer Height restriction  \
# 1087  Steel – Single-rail  Rocky Mountain Construction                NaN
#
#                 Model         Height  Inversions Lift/launch system Cost  \
# 1087  Raptor – Custom  131 ft (40 m)         3.0    Chain lift hill  NaN
#
#      Trains Park section Duration Capacity G-force Designer  \
# 1087    NaN  DC Universe      NaN      NaN     NaN      NaN
#
#      Max vertical angle           Drop Soft opening date Fast Lane available  \
# 1087                87°  127 ft (39 m)               NaN                 NaN
#
#                                     Replaced Track layout Fastrack available  \
# ...

# %%
df[df.duplicated(keep=False)] # Finds and prints both the original & duplicate records
# Out:
#                         coaster_name              Length             Speed  \
# 1086  Wonder Woman Flight of Courage  3,300 ft (1,000 m)  58 mph (93 km/h)
# 1087  Wonder Woman Flight of Courage  3,300 ft (1,000 m)  58 mph (93 km/h)
#
#                       Location              Status Opening date  \
# 1086  Six Flags Magic Mountain  Under construction         2022
# 1087  Six Flags Magic Mountain  Under construction         2022
#
#                      Type                 Manufacturer Height restriction  \
# 1086  Steel – Single-rail  Rocky Mountain Construction                NaN
# 1087  Steel – Single-rail  Rocky Mountain Construction                NaN
#
#                 Model         Height  Inversions Lift/launch system Cost  \
# 1086  Raptor – Custom  131 ft (40 m)         3.0    Chain lift hill  NaN
# 1087  Raptor – Custom  131 ft (40 m)         3.0    Chain lift hill  NaN
#
#      Trains Park section Duration Capacity G-force Designer  \
# ...

# %%
df1[df1.duplicated()]
# Out:
#      opening_date_clean  latitude
# 7                   NaT     41.58
# 9                   NaT     41.58
# 11                  NaT     41.58
# 17                  NaT     41.58
# 31                  NaT     41.58
# ...                 ...       ...
# 1082                NaT       NaN
# 1084         2016-06-16       NaN
# 1085                NaT       NaN
# 1086         2022-01-01       NaN
# 1087         2022-01-01       NaN
#
# [285 rows x 2 columns]

# %%
df1[df1.duplicated(keep=False)]
# Out:
#      opening_date_clean  latitude
# 2                   NaT   41.5800
# 7                   NaT   41.5800
# 9                   NaT   41.5800
# 11                  NaT   41.5800
# 13           1927-01-01   40.3869
# ...                 ...       ...
# 1082                NaT       NaN
# 1084         2016-06-16       NaN
# 1085                NaT       NaN
# 1086         2022-01-01       NaN
# 1087         2022-01-01       NaN
#
# [342 rows x 2 columns]

# %%
df2=df1.drop_duplicates()

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df['coaster_name'].value_counts()
# Out:
# coaster_name
# Batman: The Ride                       7
# Lego Technic Test Track                4
# Flight of the Hippogriff               4
# American Dreier Looping                4
# Big Thunder Mountain Railroad          4
#                                       ..
# Back at the Barnyard Hayride           1
# Cactus Coaster                         1
# Cannonball Express (roller coaster)    1
# Cannonball Run (roller coaster)        1
# Diving Machine G5                      1
# Name: count, Length: 990, dtype: int64

# %%
df['coaster_name'].value_counts().sort_index()
# Out:
# coaster_name
# 10 Inversion Roller Coaster     1
# Abyss (roller coaster)          1
# Abyssus                         1
# Accelerator (roller coaster)    1
# Acrobat (roller coaster)        1
#                                ..
# Zip (roller coaster)            1
# Zipper Dipper                   1
# Zippin Pippin                   2
# Zoomerang (Lake Compounce)      1
# Zydeco Scream                   1
# Name: count, Length: 990, dtype: int64

# %%
df['coaster_name'].value_counts().sort_index(ascending=False)
# Out:
# coaster_name
# Zydeco Scream                   1
# Zoomerang (Lake Compounce)      1
# Zippin Pippin                   2
# Zipper Dipper                   1
# Zip (roller coaster)            1
#                                ..
# Acrobat (roller coaster)        1
# Accelerator (roller coaster)    1
# Abyssus                         1
# Abyss (roller coaster)          1
# 10 Inversion Roller Coaster     1
# Name: count, Length: 990, dtype: int64

# %%
df['coaster_name'].value_counts().sort_values()
# Out:
# coaster_name
# Abyss (roller coaster)           1
# Lightning (Revere Beach)         1
# Racer (Kennywood)                1
# Zip (roller coaster)             1
# Alpen Blitz                      1
#                                 ..
# Big Thunder Mountain Railroad    4
# American Dreier Looping          4
# Flight of the Hippogriff         4
# Lego Technic Test Track          4
# Batman: The Ride                 7
# Name: count, Length: 990, dtype: int64

# %%
df['coaster_name']=='Batman: The Ride'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# 1087    False
# Name: coaster_name, Length: 1088, dtype: bool

# %%
df[df['coaster_name']=='Batman: The Ride']
# Out:
#          coaster_name                            Length             Speed  \
# 312  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 332  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 348  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 367  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 414  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 470  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 625  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
#
#     Location Status Opening date              Type          Manufacturer  \
# 312    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# 332    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# 348    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# 367    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# ...

# %%
df.query('''coaster_name'=='Batman: The Ride''')
# Out:
# Traceback (most recent call last):
#
#   File /opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[157], line 1
#     df.query('''coaster_name'=='Batman: The Ride''')
#
#   File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4599 in query
#     res = self.eval(expr, **kwargs)
#
#   File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4725 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/computation/eval.py:336 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:808 in __init__
#     self.terms = self.parse()
#
#   File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:827 in parse
#     return self._visitor.visit(self.expr)
#
# ...

# %%
df.query('coaster_name=="Batman: The Ride"')
# Out:
#          coaster_name                            Length             Speed  \
# 312  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 332  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 348  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 367  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 414  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 470  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 625  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
#
#     Location Status Opening date              Type          Manufacturer  \
# 312    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# 332    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# 348    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# 367    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# ...

# %%
df.query('coaster_name=="Batman: The Ride" & Type_Main=="Steel"')
# Out:
#          coaster_name                            Length             Speed  \
# 312  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 332  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 348  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 367  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 414  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 470  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
# 625  Batman: The Ride  2,693 or 2,700 ft (821 or 823 m)  50 mph (80 km/h)
#
#     Location Status Opening date              Type          Manufacturer  \
# 312    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# 332    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# 348    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# 367    Other    NaN          NaN  Steel – Inverted  Bolliger & Mabillard
# ...

# %%
df1.opening_date_clean
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# 1087   2022-01-01
# Name: opening_date_clean, Length: 1088, dtype: datetime64[ns]

# %%
df1.dtypes
# Out:
# opening_date_clean    datetime64[ns]
# latitude                     float64
# dtype: object

# %%
df1.opening_date_clean.dt.year
# Out:
# 0       1884.0
# 1       1895.0
# 2          NaN
# 3       1901.0
# 4       1901.0
#          ...
# 1083    2022.0
# 1084    2016.0
# 1085       NaN
# 1086    2022.0
# 1087    2022.0
# Name: opening_date_clean, Length: 1088, dtype: float64

# %%
df1['opening_date_clean'].dt.year # Fetch only year from a date filed
# Out:
# 0       1884.0
# 1       1895.0
# 2          NaN
# 3       1901.0
# 4       1901.0
#          ...
# 1083    2022.0
# 1084    2016.0
# 1085       NaN
# 1086    2022.0
# 1087    2022.0
# Name: opening_date_clean, Length: 1088, dtype: float64

# %%
df1['opening_date_clean'].dt.year.astype('Int32')
# Out:
# 0       1884
# 1       1895
# 2       <NA>
# 3       1901
# 4       1901
#         ...
# 1083    2022
# 1084    2016
# 1085    <NA>
# 1086    2022
# 1087    2022
# Name: opening_date_clean, Length: 1088, dtype: Int32

# %%
df1['Yr_intro_from_open_dt']=df1['opening_date_clean'].dt.year.astype('Int32') # Creating new column
# Out:
# /var/folders/8b/_vkggsks1pvdn519cywyj0_40000gn/T/ipykernel_98165/1096747876.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Yr_intro_from_open_dt']=df1['opening_date_clean'].dt.year.astype('Int32')

# %%
df1
# Out:
#      opening_date_clean  latitude  Yr_intro_from_open_dt
# 0            1884-06-16   40.5740                   1884
# 1            1895-01-01   40.5780                   1895
# 2                   NaT   41.5800                   <NA>
# 3            1901-01-01   40.5745                   1901
# 4            1901-01-01   39.3538                   1901
# ...                 ...       ...                    ...
# 1083         2022-01-01   37.2339                   2022
# 1084         2016-06-16       NaN                   2016
# 1085                NaT       NaN                   <NA>
# 1086         2022-01-01       NaN                   2022
# 1087         2022-01-01       NaN                   2022
#
# [1088 rows x 3 columns]

# %%
df1.opening_date_clean.isna().sum()
# Out:
# 250

# %%
df1.Yr_intro_from_open_dt.isna().sum()
# Out:
# 250
