# %%
import os
import pandas as pd
from sklearn.metrics import root_mean_squared_error,r2_score

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#      ID CONSOLE  YEAR      CATEGORY                     PUBLISHER RATING  \
# 0  2860      ds  2008  role-playing                      Nintendo      E
# 1   731     wii  2012    simulation  Konami Digital Entertainment   E10+
# 2   495      pc  2019       shooter                    Activision      M
# 3  2641     ps2  2002        sports               Electronic Arts      E
# 4   811     ps3  2013        action                    Activision      M
#
#    CRITICS_POINTS  USER_POINTS  SalesInMillions
# 0        2.833333     0.303704         1.779257
# 1       13.200000     1.640000         0.215050
# 2        4.562500     0.006410         0.534402
# 3        4.181818     0.326923         1.383964
# 4        2.259259     0.032579         0.082671

# %%
df.shape
# Out:
# (3506, 9)

# %%
for i in df.head().index():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 for i in df.head().index():
#       2     print(i)
#
# TypeError: 'RangeIndex' object is not callable

# %%
df1=df.head()

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
for i in df.head().index:
    # print(df['ID'][i])
    print(f"""curl -X 'POST' \
  'https://fapi-v3-1087285761306.us-central1.run.app/predict' \
  -H 'accept: application/json' \
  -H 'Content-Type: application/json' \
  -d '{{"CONSOLE":"{df['CONSOLE'][i].strip()}",\
     "YEAR":{df['YEAR'][i]},\
"CATEGORY":"{df['CATEGORY'][i].strip()}",\
"PUBLISHER":"{df['PUBLISHER'][i].strip()}",\
"RATING":"{df['RATING'][i].strip()}",\
"CRITICS_POINTS":{df['CRITICS_POINTS'][i]},\
"USER_POINTS":{df['USER_POINTS'][i]}}}'"""
      )
    print()
# Out:
# curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{"CONSOLE":"ds",     "YEAR":2008,"CATEGORY":"role-playing","PUBLISHER":"Nintendo","RATING":"E","CRITICS_POINTS":2.833333333,"USER_POINTS":0.303703704}'
#
# curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{"CONSOLE":"wii",     "YEAR":2012,"CATEGORY":"simulation","PUBLISHER":"Konami Digital Entertainment","RATING":"E10+","CRITICS_POINTS":13.2,"USER_POINTS":1.64}'
#
# curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{"CONSOLE":"pc",     "YEAR":2019,"CATEGORY":"shooter","PUBLISHER":"Activision","RATING":"M","CRITICS_POINTS":4.5625,"USER_POINTS":0.006410256}'
#
# ...

# %%
for i in df.head().index:
    print(f"""!curl -X 'POST' \
  'https://fapi-v3-1087285761306.us-central1.run.app/predict' \
  -H 'accept: application/json' \
  -H 'Content-Type: application/json' \
  -d '{{  "CONSOLE":"{df['CONSOLE'][i].strip()}", \
  "YEAR":{df['YEAR'][i]}, \
  "CATEGORY":"{df['CATEGORY'][i].strip()}", \
  "PUBLISHER":"{df['PUBLISHER'][i].strip()}", \
  "RATING":"{df['RATING'][i].strip()}", \
  "CRITICS_POINTS":{df['CRITICS_POINTS'][i]}, \
  "USER_POINTS":{df['USER_POINTS'][i]} }}'"""
    )
# Out:
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"ds",   "YEAR":2008,   "CATEGORY":"role-playing",   "PUBLISHER":"Nintendo",   "RATING":"E",   "CRITICS_POINTS":2.833333333,   "USER_POINTS":0.303703704 }'
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"wii",   "YEAR":2012,   "CATEGORY":"simulation",   "PUBLISHER":"Konami Digital Entertainment",   "RATING":"E10+",   "CRITICS_POINTS":13.2,   "USER_POINTS":1.64 }'
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"pc",   "YEAR":2019,   "CATEGORY":"shooter",   "PUBLISHER":"Activision",   "RATING":"M",   "CRITICS_POINTS":4.5625,   "USER_POINTS":0.006410256 }'
# ...

# %%
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"ds",   "YEAR":2008,   "CATEGORY":"role-playing",   "PUBLISHER":"Nintendo",   "RATING":"E",   "CRITICS_POINTS":2.833333333,   "USER_POINTS":0.303703704 }'
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"wii",   "YEAR":2012,   "CATEGORY":"simulation",   "PUBLISHER":"Konami Digital Entertainment",   "RATING":"E10+",   "CRITICS_POINTS":13.2,   "USER_POINTS":1.64 }'
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"pc",   "YEAR":2019,   "CATEGORY":"shooter",   "PUBLISHER":"Activision",   "RATING":"M",   "CRITICS_POINTS":4.5625,   "USER_POINTS":0.006410256 }'
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"ps2",   "YEAR":2002,   "CATEGORY":"sports",   "PUBLISHER":"Electronic Arts",   "RATING":"E",   "CRITICS_POINTS":4.181818182,   "USER_POINTS":0.326923077 }'
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"ps3",   "YEAR":2013,   "CATEGORY":"action",   "PUBLISHER":"Activision",   "RATING":"M",   "CRITICS_POINTS":2.259259259,   "USER_POINTS":0.032579186 }'
# Out:
# {"SalesInMillions":2.7618037736311285}{"SalesInMillions":1.245571349083759}{"SalesInMillions":1.5001873418255187}{"SalesInMillions":3.1130937376029655}{"SalesInMillions":2.397739204562476}

# %%
{"SalesInMillions":2.7618037736311285}{"SalesInMillions":1.245571349083759}{"SalesInMillions":1.5001873418255187}{"SalesInMillions":3.1130937376029655}{"SalesInMillions":2.397739204562476}
# Out:
#   Cell In[88], line 1
#     {"SalesInMillions":2.7618037736311285}{"SalesInMillions":1.245571349083759}{"SalesInMillions":1.5001873418255187}{"SalesInMillions":3.1130937376029655}{"SalesInMillions":2.397739204562476}
#                                           ^
# SyntaxError: invalid syntax

# %%
import json

# %%
response_str = '{"SalesInMillions":2.7618037736311285}{"SalesInMillions":1.245571349083759}{"SalesInMillions":1.5001873418255187}{"SalesInMillions":3.1130937376029655}{"SalesInMillions":2.397739204562476}'

# %%
json_objects = response_str.split('}{')

# %%
json_objects
# Out:
# ['{"SalesInMillions":2.7618037736311285',
#  '"SalesInMillions":1.245571349083759',
#  '"SalesInMillions":1.5001873418255187',
#  '"SalesInMillions":3.1130937376029655',
#  '"SalesInMillions":2.397739204562476}']

# %%
json_objects = [obj+'}' if i == 0 else '{'+obj+'}' for i, obj in enumerate(json_objects)]
json_objects
# Out:
# ['{"SalesInMillions":2.7618037736311285}}}',
#  '{{{"SalesInMillions":1.245571349083759}}}',
#  '{{{"SalesInMillions":1.5001873418255187}}}',
#  '{{{"SalesInMillions":3.1130937376029655}}}',
#  '{{{"SalesInMillions":2.397739204562476}}}}']

# %%
for i, obj in enumerate(json_objects):
    # print(i,obj)
    if i == 0:
        print('inside if:',obj+'}')
    else:
        print('inside esle:','{'+obj+'}')
# Out:
# inside if: {"SalesInMillions":2.7618037736311285}}
# inside esle: {{"SalesInMillions":1.245571349083759}}
# inside esle: {{"SalesInMillions":1.5001873418255187}}
# inside esle: {{"SalesInMillions":3.1130937376029655}}
# inside esle: {{"SalesInMillions":2.397739204562476}}}

# %%
json_objects
# Out:
# ['{"SalesInMillions":2.7618037736311285}',
#  '{"SalesInMillions":1.245571349083759}',
#  '{"SalesInMillions":1.5001873418255187}',
#  '{"SalesInMillions":3.1130937376029655}',
#  '{"SalesInMillions":2.397739204562476}}']

# %%
json_objects = [obj+'}' if i == 0 else '{'+obj+'}' for i, obj in enumerate(json_objects)]
json_objects
# Out:
# ['{"SalesInMillions":2.7618037736311285}}',
#  '{{"SalesInMillions":1.245571349083759}}',
#  '{{"SalesInMillions":1.5001873418255187}}',
#  '{{"SalesInMillions":3.1130937376029655}}',
#  '{{"SalesInMillions":2.397739204562476}}}']

# %%
for i in json_objects:
    print(i)
# Out:
# {"SalesInMillions":2.7618037736311285}}}
# {{{"SalesInMillions":1.245571349083759}}}
# {{{"SalesInMillions":1.5001873418255187}}}
# {{{"SalesInMillions":3.1130937376029655}}}
# {{{"SalesInMillions":2.397739204562476}}}}

# %%
json_objects = response_str.split('}{')
print(json_objects)
json_objects1 = [obj+'}' if i == 0 else '{'+obj+'}' for i, obj in enumerate(json_objects)]
print(json_objects1)
# Parse each JSON object and extract the "SalesInMillions" value

sales_values = [json.loads(obj)['SalesInMillions'] for obj in json_objects]
# Out:
# ['{"SalesInMillions":2.7618037736311285', '"SalesInMillions":1.245571349083759', '"SalesInMillions":1.5001873418255187', '"SalesInMillions":3.1130937376029655', '"SalesInMillions":2.397739204562476}']
# ['{"SalesInMillions":2.7618037736311285}', '{"SalesInMillions":1.245571349083759}', '{"SalesInMillions":1.5001873418255187}', '{"SalesInMillions":3.1130937376029655}', '{"SalesInMillions":2.397739204562476}}']
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[118], line 7
#       4 print(json_objects1)
#       5 # Parse each JSON object and extract the "SalesInMillions" value
# ----> 7 sales_values = [json.loads(obj)['SalesInMillions'] for obj in json_objects]
#
# File ~/Documents/GitHub/DataScience/.conda/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
response_str = '{"SalesInMillions":2.7618037736311285}{"SalesInMillions":1.245571349083759}{"SalesInMillions":1.5001873418255187}{"SalesInMillions":3.1130937376029655}{"SalesInMillions":2.397739204562476}'
# Split correctly by adding a comma between '}' and '{' to make it a proper list of JSON objects
json_str = response_str.replace('}{', '},{')
print(json_str)
# Wrapping the split JSON strings in square brackets to make it a proper JSON list
json_str = f"[{json_str}]"
print(json_str)
# Parse the JSON string into Python list of dictionaries
json_objects = json.loads(json_str)
print(json_objects)
# Extract the "SalesInMillions" values
sales_values = [obj['SalesInMillions'] for obj in json_objects]

print(sales_values)
# Out:
# {"SalesInMillions":2.7618037736311285},{"SalesInMillions":1.245571349083759},{"SalesInMillions":1.5001873418255187},{"SalesInMillions":3.1130937376029655},{"SalesInMillions":2.397739204562476}
# [{"SalesInMillions":2.7618037736311285},{"SalesInMillions":1.245571349083759},{"SalesInMillions":1.5001873418255187},{"SalesInMillions":3.1130937376029655},{"SalesInMillions":2.397739204562476}]
# [{'SalesInMillions': 2.7618037736311285}, {'SalesInMillions': 1.245571349083759}, {'SalesInMillions': 1.5001873418255187}, {'SalesInMillions': 3.1130937376029655}, {'SalesInMillions': 2.397739204562476}]
# [2.7618037736311285, 1.245571349083759, 1.5001873418255187, 3.1130937376029655, 2.397739204562476]

# %%
for i in df.index:
    print(f"""curl -X 'POST' \
  'https://fapi-v3-1087285761306.us-central1.run.app/predict' \
  -H 'accept: application/json' \
  -H 'Content-Type: application/json' \
  -d '{{  "CONSOLE":"{df['CONSOLE'][i].strip()}", \
  "YEAR":{df['YEAR'][i]}, \
  "CATEGORY":"{df['CATEGORY'][i].strip()}", \
  "PUBLISHER":"{df['PUBLISHER'][i].strip()}", \
  "RATING":"{df['RATING'][i].strip()}", \
  "CRITICS_POINTS":{df['CRITICS_POINTS'][i]}, \
  "USER_POINTS":{df['USER_POINTS'][i]} }}'"""
    )
# Out:
# curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"ds",   "YEAR":2008,   "CATEGORY":"role-playing",   "PUBLISHER":"Nintendo",   "RATING":"E",   "CRITICS_POINTS":2.833333333,   "USER_POINTS":0.303703704 }'
# curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"wii",   "YEAR":2012,   "CATEGORY":"simulation",   "PUBLISHER":"Konami Digital Entertainment",   "RATING":"E10+",   "CRITICS_POINTS":13.2,   "USER_POINTS":1.64 }'
# curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"pc",   "YEAR":2019,   "CATEGORY":"shooter",   "PUBLISHER":"Activision",   "RATING":"M",   "CRITICS_POINTS":4.5625,   "USER_POINTS":0.006410256 }'
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Documents/GitHub/DataScience/.conda/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3368, in InteractiveShell.transform_cell(self, raw_cell)
#    3355 """Transform an input cell before parsing it.
#    3356
#    3357 Static transformations, implemented in IPython.core.inputtransformer2,
#    (...)
#    3365 see :meth:`transform_ast`.
#    3366 """
#    3367 # Static input transformations
# -> 3368 cell = self.input_transformer_manager.transform_cell(raw_cell)
#    3370 if len(cell.splitlines()) == 1:
#    3371     # Dynamic transformations - only applied for single line commands
#    3372     with self.builtin_trap:
#    3373         # use prefilter_lines to handle trailing newlines
#    3374         # restore trailing newline for ast.parse
#
# ...

# %%
response_str = '{"SalesInMillions":2.7618037736311285}{"SalesInMillions":1.245571349083759}{"SalesInMillions":1.5001873418255187}{"SalesInMillions":3.1130937376029655}{"SalesInMillions":2.397739204562476}'

json_str=response_str.replace('}{','},{')

# %%
json_str
# Out:
# '{"SalesInMillions":2.7618037736311285},{"SalesInMillions":1.245571349083759},{"SalesInMillions":1.5001873418255187},{"SalesInMillions":3.1130937376029655},{"SalesInMillions":2.397739204562476}'

# %%
os.getcwd()
# Out:
# '/Users/bkannadasan/Documents/GitHub/DataScience/MachineLearning/Linear_regression_practice/Walkathon2'

# %%
with open ('output.txt','r') as f:
    data = json.load(f)
data
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[135], line 2
#       1 with open ('output.txt','r') as f:
# ----> 2     data = json.load(f)
#       3 data
#
# File ~/Documents/GitHub/DataScience/.conda/lib/python3.12/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# ...

# %%
f=open('output.txt','r')
data=f.read()
data
# Out:
# '{"SalesInMillions":2.7618037736311285}{"SalesInMillions":1.245571349083759}{"SalesInMillions":1.5001873418255187}{"SalesInMillions":3.1130937376029655}{"SalesInMillions":2.397739204562476}{"SalesInMillions":2.8752187724673597}{"SalesInMillions":0.841428507642284}{"SalesInMillions":2.3326651305352852}{"SalesInMillions":2.2216076158978066}{"SalesInMillions":2.1358464371647314}{"SalesInMillions":2.161967943205203}{"SalesInMillions":3.1208251866136725}{"SalesInMillions":2.3924612887720236}{"SalesInMillions":0.558408767576813}{"SalesInMillions":2.8716374695590114}{"SalesInMillions":1.6960459317087662}{"SalesInMillions":0.7602756249568849}{"SalesInMillions":1.9700732031524841}{"SalesInMillions":2.020809368218148}{"SalesInMillions":2.5528092507638647}{"SalesInMillions":2.8654488019525584}{"SalesInMillions":2.3560643579563663}{"SalesInMillions":2.349652388082733}{"SalesInMillions":2.64285931101235}{"SalesInMillions":2.1481459540432324}{"SalesInMillions":3.144097441058399}{"SalesInMillions":
# ...

# %%
data=data.replace('}{','},{')

# %%
data
# Out:
# '{"SalesInMillions":2.7618037736311285},{"SalesInMillions":1.245571349083759},{"SalesInMillions":1.5001873418255187},{"SalesInMillions":3.1130937376029655},{"SalesInMillions":2.397739204562476},{"SalesInMillions":2.8752187724673597},{"SalesInMillions":0.841428507642284},{"SalesInMillions":2.3326651305352852},{"SalesInMillions":2.2216076158978066},{"SalesInMillions":2.1358464371647314},{"SalesInMillions":2.161967943205203},{"SalesInMillions":3.1208251866136725},{"SalesInMillions":2.3924612887720236},{"SalesInMillions":0.558408767576813},{"SalesInMillions":2.8716374695590114},{"SalesInMillions":1.6960459317087662},{"SalesInMillions":0.7602756249568849},{"SalesInMillions":1.9700732031524841},{"SalesInMillions":2.020809368218148},{"SalesInMillions":2.5528092507638647},{"SalesInMillions":2.8654488019525584},{"SalesInMillions":2.3560643579563663},{"SalesInMillions":2.349652388082733},{"SalesInMillions":2.64285931101235},{"SalesInMillions":2.1481459540432324},{"SalesInMillions":3.1440974410
# ...

# %%
json_str= f'[{data}]'

# %%
json_data=json.load(json_str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 json_data=json.load(json_str)
#
# File ~/Documents/GitHub/DataScience/.conda/lib/python3.12/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# ...

# %%
json_data=json.loads(json_str)

# %%
json_data
# Out:
# [{'SalesInMillions': 2.7618037736311285},
#  {'SalesInMillions': 1.245571349083759},
#  {'SalesInMillions': 1.5001873418255187},
#  {'SalesInMillions': 3.1130937376029655},
#  {'SalesInMillions': 2.397739204562476},
#  {'SalesInMillions': 2.8752187724673597},
#  {'SalesInMillions': 0.841428507642284},
#  {'SalesInMillions': 2.3326651305352852},
#  {'SalesInMillions': 2.2216076158978066},
#  {'SalesInMillions': 2.1358464371647314},
#  {'SalesInMillions': 2.161967943205203},
#  {'SalesInMillions': 3.1208251866136725},
#  {'SalesInMillions': 2.3924612887720236},
#  {'SalesInMillions': 0.558408767576813},
#  {'SalesInMillions': 2.8716374695590114},
#  {'SalesInMillions': 1.6960459317087662},
#  {'SalesInMillions': 0.7602756249568849},
#  {'SalesInMillions': 1.9700732031524841},
#  {'SalesInMillions': 2.020809368218148},
#  {'SalesInMillions': 2.5528092507638647},
#  {'SalesInMillions': 2.8654488019525584},
#  {'SalesInMillions': 2.3560643579563663},
# ...

# %%
len(json_data)
# Out:
# 2614

# %%
sales_val = [obj['SalesInMillions'] for obj in json_data]

# %%
len(sales_val)
# Out:
# 2614

# %%
f=open('output.txt','r')
raw_data=f.read()
formatted_data=raw_data.replace('}{','},{')
json_lst=f"[{formatted_data}]"
json_data=json.loads(json_lst)
sales_val = [i['SalesInMillions'] for i in json_data ]
len(sales_val)
print(type(sales_val))
df1 = pd.DataFrame(sales_val,columns=['predicted_sales'])
# Out:
# <class 'list'>

# %%
df1
# Out:
#       predicted_sales
# 0            2.761804
# 1            1.245571
# 2            1.500187
# 3            3.113094
# 4            2.397739
# ...               ...
# 3501         2.608129
# 3502         1.991008
# 3503         1.831298
# 3504         1.917483
# 3505         0.848599
#
# [3506 rows x 1 columns]

# %%
df
# Out:
#         ID CONSOLE  YEAR      CATEGORY  \
# 0     2860      ds  2008  role-playing
# 1      731     wii  2012    simulation
# 2      495      pc  2019       shooter
# 3     2641     ps2  2002        sports
# 4      811     ps3  2013        action
# ...    ...     ...   ...           ...
# 3501  1323      ds  2007  role-playing
# 3502  2862     3ds  2018        action
# 3503  1980     ps3  2012        action
# 3504  3065     3ds  2016    simulation
# 3505  3722      gc  2005      platform
#
#                                    PUBLISHER RATING  CRITICS_POINTS  \
# 0                                   Nintendo      E        2.833333
# 1               Konami Digital Entertainment   E10+       13.200000
# 2                                 Activision      M        4.562500
# 3                            Electronic Arts      E        4.181818
# 4                                 Activision      M        2.259259
# ...                                      ...    ...             ...
# ...

# %%
df['predicted_sales'] = pd.DataFrame(sales_val)

# %%
df
# Out:
#         ID CONSOLE  YEAR      CATEGORY  \
# 0     2860      ds  2008  role-playing
# 1      731     wii  2012    simulation
# 2      495      pc  2019       shooter
# 3     2641     ps2  2002        sports
# 4      811     ps3  2013        action
# ...    ...     ...   ...           ...
# 3501  1323      ds  2007  role-playing
# 3502  2862     3ds  2018        action
# 3503  1980     ps3  2012        action
# 3504  3065     3ds  2016    simulation
# 3505  3722      gc  2005      platform
#
#                                    PUBLISHER RATING  CRITICS_POINTS  \
# 0                                   Nintendo      E        2.833333
# 1               Konami Digital Entertainment   E10+       13.200000
# 2                                 Activision      M        4.562500
# 3                            Electronic Arts      E        4.181818
# 4                                 Activision      M        2.259259
# ...                                      ...    ...             ...
# ...

# %%
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"ds",   "YEAR":2008,   "CATEGORY":"role-playing",   "PUBLISHER":"Nintendo",   "RATING":"E",   "CRITICS_POINTS":2.833333333,   "USER_POINTS":0.303703704 }'
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"wii",   "YEAR":2012,   "CATEGORY":"simulation",   "PUBLISHER":"Konami Digital Entertainment",   "RATING":"E10+",   "CRITICS_POINTS":13.2,   "USER_POINTS":1.64 }'
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"pc",   "YEAR":2019,   "CATEGORY":"shooter",   "PUBLISHER":"Activision",   "RATING":"M",   "CRITICS_POINTS":4.5625,   "USER_POINTS":0.006410256 }'
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"3ds",   "YEAR":2016,   "CATEGORY":"simulation",   "PUBLISHER":"Marvelous Entertainment",   "RATING":"E10+",   "CRITICS_POINTS":2.571428571,   "USER_POINTS":0.464285714 }'
# !curl -X 'POST'   'https://fapi-v3-1087285761306.us-central1.run.app/predict'   -H 'accept: application/json'   -H 'Content-Type: application/json'   -d '{  "CONSOLE":"gc",   "YEAR":2005,   "CATEGORY":"platform",   "PUBLISHER":"Thq",   "RATING":"E",   "CRITICS_POINTS":4.411764706,   "USER_POINTS":2.325 }'
# Out:
# {"SalesInMillions":2.7618037736311285}{"SalesInMillions":1.245571349083759}{"SalesInMillions":1.5001873418255187}{"SalesInMillions":1.9174833604493322}{"SalesInMillions":0.8485985489238626}

# %%
df2=df[['SalesInMillions','predicted_sales']]

# %%
df2
# Out:
#       SalesInMillions  predicted_sales
# 0            1.779257         2.761804
# 1            0.215050         1.245571
# 2            0.534402         1.500187
# 3            1.383964         3.113094
# 4            0.082671         2.397739
# ...               ...              ...
# 3501         3.584264         2.608129
# 3502         2.701472         1.991008
# 3503         1.631668         1.831298
# 3504         2.899156         1.917483
# 3505         1.221262         0.848599
#
# [3506 rows x 2 columns]

# %%
root_mean_squared_error(df2['SalesInMillions'],df2['predicted_sales'])
# Out:
# np.float64(2.421237674394405)

# %%
r2_score(df2['SalesInMillions'],df2['predicted_sales'])
# Out:
# 0.058284347822982085

# %%
f=open('output.txt','r')
raw_data=f.read()
formatted_data=raw_data.replace('}{','},{')
json_lst=f"[{formatted_data}]"
json_data=json.loads(json_lst)
sales_val = [i['SalesInMillions'] for i in json_data ]
print(df.shape)
len(sales_val)
print(type(sales_val),len(sales_val))
df1 = pd.DataFrame(sales_val,columns=['predicted_sales'])
df.drop(columns=['predicted_sales'])
df['predicted_sales'] = pd.DataFrame(sales_val)
df2=df[['SalesInMillions','predicted_sales']]
print(root_mean_squared_error(df2['SalesInMillions'],df2['predicted_sales']))
print(r2_score(df2['SalesInMillions'],df2['predicted_sales']))
# Out:
# (3506, 10)
# <class 'list'> 3506
# 2.421237674394405
# 0.058284347822982085
