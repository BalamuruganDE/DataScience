# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib inline
import seaborn as sns
import os

# %%
# !pwd
# Out:
# /Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis

# %%
os.getcwd()
# Out:
# '/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis'

# %%
# !cd /Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis

# %%
os.chdir('/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis')

# %%
# !pwd
# Out:
# /Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis

# %%
fifa = pd.read_csv('fifa.csv')

# %%
fifa
# Out:
#            Date   ARG  BRA   ESP   FRA  GER   ITA
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ..          ...   ...  ...   ...   ...  ...   ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 7 columns]

# %%
type(fifa)
# Out:
# pandas.core.frame.DataFrame

# %%
fifa1=pd.read_csv('fifa.csv',index_col=['Date'],parse_dates=True)

# %%
type(fifa1)
# Out:
# pandas.core.frame.DataFrame

# %%
fifa1
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
sns.lineplot(data=fifa1)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=fifa1)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date'>

# %%
fifa = pd.read_csv('/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis/fifa.csv')

# %%
fifa
# Out:
#            Date   ARG  BRA   ESP   FRA  GER   ITA
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ..          ...   ...  ...   ...   ...  ...   ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 7 columns]

# %%
fifa = pd.read_csv('/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis/fifa.csv',index_col=['Date'])

# %%
fifa
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
fifa = pd.read_csv('/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis/fifa.csv',index_col="Date",parse_dates=True)
fifa
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
fifa.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
sns.lineplot(data=fifa)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=fifa)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date'>

# %%
spotify=pd.read_csv('spotify.csv')
spotify
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# ...

# %%
spotify=pd.read_csv('spotify.csv',index_col='Date',parse_dates=True)
spotify
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=spotify)
plt.title('Popular song streams in spotify 2017-2018')
plt.xlabel('Dates from 2017-2018')
plt.ylabel('Streams in millions')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Streams in millions')

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=spotify['Despacito'])
sns.lineplot(data=spotify['Shape of You'])
plt.title('Popular song streams in spotify 2017-2018')
plt.xlabel('Dates from 2017-2018')
plt.ylabel('Streams in millions')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
spotify=pd.read_csv('/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis/spotify.csv')
spotify
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# ...

# %%
spotify = pd.read_csv('/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis/spotify.csv',index_col='Date',parse_dates=True)

# %%
sns.lineplot(data=spotify)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=spotify)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=spotify)
plt.title("Popular song streams in spotify from 2017-2018")
plt.xlabel("Dates from 2017-2018")
plt.ylabel('Streams')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Streams')

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=spotify['Despacito'])
sns.lineplot(data=spotify['Shape of You'])
plt.title("Popular song streams in spotify from 2017-2018")
plt.xlabel("Dates from 2017-2018")
plt.ylabel('Streams')
plt.legend(['Despacito','Shape of You'])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=spotify['Shape of You'])
plt.title("Popular song streams in spotify from 2017-2018")
plt.xlabel("Dates from 2017-2018")
plt.ylabel('Streams')
plt.legend('Despacito','Shape of You')


plt.figure(figsize=(16,6))
sns.lineplot(data=spotify['Despacito'])
plt.title("Popular song streams in spotify from 2017-2018")
plt.xlabel("Dates from 2017-2018")
plt.ylabel('Streams')
plt.legend('Despacito','Shape of You')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/8b/_vkggsks1pvdn519cywyj0_40000gn/T/ipykernel_68058/3444097080.py:6: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   plt.legend('Despacito','Shape of You')
# ...

# %%
flightDelay=pd.read_csv('/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis/flight_delays.csv')
flightDelay
# Out:
#     Month        AA        AS         B6        DL         EV         F9  \
# 0       1  6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 1       2  7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 2       3  6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 3       4  4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 4       5  5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 5       6  8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 6       7  3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 7       8  3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 8       9 -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 9      10 -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 10     11  0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 11     12  4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
flightDelay=pd.read_csv('/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis/flight_delays.csv',index_col="Month",parse_dates=True)
flightDelay
# Out:
# /var/folders/8b/_vkggsks1pvdn519cywyj0_40000gn/T/ipykernel_2834/4021685272.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flightDelay=pd.read_csv('/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis/flight_delays.csv',index_col="Month",parse_dates=True)
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# ...

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=flightDelay.index,y=flightDelay['AA'])

# sns.barplot(x=flightDelay.index,y=flightDelay.all)
# Out:
# <Axes: xlabel='Month', ylabel='AA'>

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=flightDelay.index,y=flightDelay['NK'])
# Out:
# <Axes: xlabel='Month', ylabel='NK'>

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=flightDelay.index,y=flightDelay.all)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 plt.figure(figsize=(16,6))
# ----> 2 sns.barplot(x=flightDelay.index,y=flightDelay.all)
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# ...

# %%
#Spotify - plot percentage of missing values along Y - Column names along X
# print(spotify.isna())

print(spotify.isna().sum())

y=spotify.isna().sum()
# Out:
# Date                         0
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
NA = (spotify.isna().sum()/len(spotify))*100
NA = pd.DataFrame(NA,columns='count')
print(len(spotify))
print(spotify.shape)
NA
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 2
#       1 NA = (spotify.isna().sum()/len(spotify))*100
# ----> 2 NA = pd.DataFrame(NA,columns='count')
#       3 print(len(spotify))
#       4 print(spotify.shape)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     771         mgr = dict_to_mgr(
#     772             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     773             # attribute "name"
#    (...)
#     779             copy=_copy,
#     780         )
#     781     else:
# --> 782         mgr = ndarray_to_mgr(
#     783             data,
#     784             index,
#     785             columns,
#     786             dtype=dtype,
#     787             copy=copy,
#     788             typ=manager,
#     789         )
# ...

# %%
NA = (spotify.isna().sum()/len(spotify))*100
NA = pd.DataFrame(NA,columns=['count'])
print(len(spotify))
print(spotify.shape)
NA.index.names=['Name']
NA
# sns.barplot(x=NA['Name'],y=NA['count'])
# Out:
# 366
# (366, 5)
#                               count
# Name
# Shape of You               0.000000
# Despacito                  1.912568
# Something Just Like This  12.841530
# HUMBLE.                   22.950820
# Unforgettable             24.863388

# %%
# print(spotify.isna())
# print(spotify.isna().sum())
# print(spotify.isna().sum()/len(spotify))
NA = (spotify.isna().sum()/len(spotify))*100
print('Value of NA',NA)
NA = pd.DataFrame(NA,columns=['Percentage(%) of Missing Data'])
print('Value of modified NA',NA)
print(len(spotify))
print(spotify.shape)
print(NA)

NA.index.names=['Name']
# NA.reset_
print(NA)

sns.barplot(x=NA.index,y=NA['Percentage(%) of Missing Data']) # method 1
# sns.barplot(x='Name',y='Percentage(%) of Missing Data',data=NA) # method 2

# plt.xticks(rotation=90)
plt.xticks(rotation=45)
# Out:
# Value of NA Name
# Shape of You                 0.000000
# Despacito                    1.912568
# Something Just Like This    12.841530
# HUMBLE.                     22.950820
# Unforgettable               24.863388
# dtype: float64
# Value of modified NA                           Percentage(%) of Missing Data
# Name
# Shape of You                                   0.000000
# Despacito                                      1.912568
# Something Just Like This                      12.841530
# HUMBLE.                                       22.950820
# Unforgettable                                 24.863388
# 366
# (366, 5)
#                           Percentage(%) of Missing Data
# Name
# Shape of You                                   0.000000
# Despacito                                      1.912568
# Something Just Like This                      12.841530
# HUMBLE.                                       22.950820
# Unforgettable                                 24.863388
# ...

# %%
colors=sns.color_palette("hsv", len(NA))
sns.barplot(x = ['Name'], y = ['count'], data = NA, palette=colors)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/8b/_vkggsks1pvdn519cywyj0_40000gn/T/ipykernel_2834/1734777471.py in ?()
#       1 colors=sns.color_palette("hsv", len(NA))
# ----> 2 sns.barplot(x = ['Name'], y = ['count'], data = NA, palette=colors)
#
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py in ?(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2751     # does not work in Series.agg (maybe a pandas bug?)
#    2752     if estimator is len:
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
# ...

# %%
# (Or)
colors = ['red', 'blue', 'green', 'purple']
sns.barplot(x = 'Name', y = 'count', data = NA, palette=colors)

# %%
# !pip install seaborn
# Out:
# Looking in indexes: https://bkannadasan:****@artylab.expedia.biz/api/pypi/public-pypi-virtual/simple
# ...
# WARNING: 401 Error, Credentials not correct for https://artylab.expedia.biz/api/pypi/public-pypi-virtual/simple/pip/

# %%
plt.figure(figsize=(16,6))
plt.title('Average Arrival Delays for each of the flights, by month')
flightDelay
corr = flightDelay.corr()
# print(corr)
sns.heatmap(corr,vmin=-1,vmax=1,center=0,annot=True)
# Out:
# <Axes: title={'center': 'Average Arrival Delays for each of the flights, by month'}>

# %%
insurance = pd.read_csv('/Users/bkannadasan/Desktop/Mylearings/DSAI/data-for-datavis/')
