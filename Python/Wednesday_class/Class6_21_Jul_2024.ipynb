# %%
import pandas as pd

# %%
data1 = [101,102,103]
print(data1,type(data1))
# Out:
# [101, 102, 103] <class 'list'>

# %%
field1=pd.Series(data1)
print(field1,type(field1))
# Out:
# 0    101
# 1    102
# 2    103
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
data2=['Sree','Sai','Kishore']
print(data2,type(data2))
# Out:
# ['Sree', 'Sai', 'Kishore'] <class 'list'>

# %%
field2=pd.Series(data2)
print(field2,type(field2))
# Out:
# 0       Sree
# 1        Sai
# 2    Kishore
# dtype: object <class 'pandas.core.series.Series'>

# %%
df1=pd.DataFrame({'eid':field1,'ename':field2})
print(df1,'\n',type(df1))
# Out:
#    eid    ename
# 0  101     Sree
# 1  102      Sai
# 2  103  Kishore
#  <class 'pandas.core.frame.DataFrame'>

# %%
df1=pd.DataFrame({'eid':data1,'ename':data2})
print(df1,'\n',type(df1))
# Out:
#    eid    ename
# 0  101     Sree
# 1  102      Sai
# 2  103  Kishore
#  <class 'pandas.core.frame.DataFrame'>

# %%
dict1={'eid':data1,'ename':data2}
dict1
# Out:
# {'eid': [101, 102, 103], 'ename': ['Sree', 'Sai', 'Kishore']}

# %%
df1=pd.DataFrame(dict1)
df1
# Out:
#    eid    ename
# 0  101     Sree
# 1  102      Sai
# 2  103  Kishore

# %%
df1=pd.DataFrame(dict1,index=['r1','r2','r3'])
df1
# Out:
#     eid    ename
# r1  101     Sree
# r2  102      Sai
# r3  103  Kishore

# %%
df1.loc['r2']
# Out:
# eid      102
# ename    Sai
# Name: r2, dtype: object

# %%
df1['eid']
# Out:
# r1    101
# r2    102
# r3    103
# Name: eid, dtype: int64

# %%
df1.loc['eid']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'eid'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df1.loc['eid']
#
# ...

# %%
df1.loc[:,'eid']
# Out:
# r1    101
# r2    102
# r3    103
# Name: eid, dtype: int64

# %%
df1.iloc[0,0]
# Out:
# 101

# %%
df1.iloc[2,1]# 2nd row index and 1st column index
# Out:
# 'Kishore'

# %%
for i in df1.iloc[2,1]:
    print(i)
# Out:
# K
# i
# s
# h
# o
# r
# e

# %%
df1[df1['ename'] == 'Kishore']
# Out:
#     eid    ename
# r3  103  Kishore

# %%
df1[df1['eid'] == 102]
# Out:
#     eid ename
# r2  102   Sai

# %%
df1[df1['eid'] > 101]
# Out:
#     eid    ename
# r2  102      Sai
# r3  103  Kishore

# %%
df1[df1['eid'] > 101]
# Out:
#     eid    ename
# r2  102      Sai
# r3  103  Kishore

# %%
df1[df1['eid'] %2 ==0]
# Out:
#     eid ename
# r2  102   Sai

# %%
df1[df1['eid'] %2 ==1]
# Out:
#     eid    ename
# r1  101     Sree
# r3  103  Kishore

# %%
df1[df1['eid'] %2 ==1]['ename']
# Out:
# r1       Sree
# r3    Kishore
# Name: ename, dtype: object

# %%
df1[df1['eid'] %2 ==1][['eid','ename']]
# Out:
#     eid    ename
# r1  101     Sree
# r3  103  Kishore

# %%
df1[df1['eid'] %2 ==1][:]
# Out:
#     eid    ename
# r1  101     Sree
# r3  103  Kishore

# %%
df1[df1['eid'] %2 ==1][::-1]
# Out:
#     eid    ename
# r3  103  Kishore
# r1  101     Sree

# %%
df2=pd.read_csv('Dataset/emp_data.csv')
df2
# Out:
#    eid    ename
# 0  101     Sree
# 1  102      Sai
# 2  103  Kishore

# %%
{'eid': {"0":101, "1":102, "2":103}, 'ename': {"0":'Sree',"1":'Sai', "2":'Kishore'}}
# Out:
# {'eid': {'0': 101, '1': 102, '2': 103},
#  'ename': {'0': 'Sree', '1': 'Sai', '2': 'Kishore'}}

# %%
df2=pd.read_csv('Dataset/emp_data.json')
df2
# Out:
# Empty DataFrame
# Columns: [{'eid': {"0":101,  "1":102,  "2":103},  'ename': {"0":'Sree', 1:'Sai',  "2":'Kishore'}}]
# Index: []

# %%
df3=pd.read_json('Dataset/emp_data.json')
df3
# Out:
#    eid    ename
# 0  101     Sree
# 1  102      Sai
# 2  103  Kishore

# %%
url = "https://support.staffbase.com/hc/en-us/article_attachments/360009159392/access-code.csv"
df3=pd.read_csv(url,delimiter=';')
print(df3)
df4=pd.read_csv(url,sep=';')
df4
# Out:
#    Identifier First name Last name
# 0      901242     Rachel    Booker
# 1      207074      Laura      Grey
# 2      408129      Craig   Johnson
# 3      934600       Mary   Jenkins
# 4      507916      Jamie     Smith
#    Identifier First name Last name
# 0      901242     Rachel    Booker
# 1      207074      Laura      Grey
# 2      408129      Craig   Johnson
# 3      934600       Mary   Jenkins
# 4      507916      Jamie     Smith

# %%
url = "https://en.wikipedia.org/wiki/Administrative_divisions_of_India"

df5=pd.read_html(url)
print(df5)
len(df5)
# Out:
# [    0                                                  1
# 0 NaN  This article possibly contains original resear...,                                                     0
# 0             This article is part of a series on the
# 1                                   Politics of India
# 2   Constitution and law Constitution of India Fun...
# 3   Government President of India Droupadi Murmu V...
# 4   Parliament Parliament of India Lok Sabha Speak...
# 5   Judiciary Supreme Court of India Chief Justice...
# 6   Elections and political parties Presidential e...
# 7   Administrative divisions States Andhra Pradesh...
# 8   Federalism Executive Governors (List) Lieutena...
# 9   Foreign relations Ministry of External Affairs...
# 10                       India portal Other countries
# 11                                                vte,     0   1   2   3                                                  4   \
# 0  NaN NaN NaN NaN                                                NaN
# ...

# %%
print(df5[0])
print(df5[1])
print(df5[2])
# Out:
#     0                                                  1
# 0 NaN  This article possibly contains original resear...
#                                                     0
# 0             This article is part of a series on the
# 1                                   Politics of India
# 2   Constitution and law Constitution of India Fun...
# 3   Government President of India Droupadi Murmu V...
# 4   Parliament Parliament of India Lok Sabha Speak...
# 5   Judiciary Supreme Court of India Chief Justice...
# 6   Elections and political parties Presidential e...
# 7   Administrative divisions States Andhra Pradesh...
# 8   Federalism Executive Governors (List) Lieutena...
# 9   Foreign relations Ministry of External Affairs...
# 10                       India portal Other countries
# 11                                                vte
#     0   1   2   3                                                  4   \
# 0  NaN NaN NaN NaN                                                NaN
# ...

# %%
type(df5[2])
# Out:
# pandas.core.frame.DataFrame

# %%
df5[2].shape
# Out:
# (30, 18)

# %%
df5[2]
# Out:
#     0   1   2   3                                                  4   \
# 0  NaN NaN NaN NaN                                                NaN
# 1  NaN NaN NaN NaN                                                NaN
# 2  NaN NaN NaN NaN                                    Country (India)
# 3  NaN NaN NaN NaN                                    Country (India)
# 4  NaN NaN NaN NaN                                                NaN
# 5  NaN NaN NaN NaN                                                NaN
# 6  NaN NaN NaN NaN                     State (e.g. West Bengal State)
# 7  NaN NaN NaN NaN                     State (e.g. West Bengal State)
# 8  NaN NaN NaN NaN                                                NaN
# 9  NaN NaN NaN NaN                                                NaN
# 10 NaN NaN NaN NaN                Division (e.g. Presidency Division)
# 11 NaN NaN NaN NaN                Division (e.g. Presidency Division)
# ...

# %%
df5[4].shape
# Out:
# (28, 11)

# %%
df5[4]
# Out:
#                 State    ISO Vehicle code           Zone  \
# 0      Andhra Pradesh  IN-AP           AP       Southern
# 1   Arunachal Pradesh  IN-AR           AR  North-Eastern
# 2               Assam  IN-AS           AS  North-Eastern
# 3               Bihar  IN-BR           BR        Eastern
# 4        Chhattisgarh  IN-CG           CG        Central
# 5                 Goa  IN-GA           GA        Western
# 6             Gujarat  IN-GJ           GJ        Western
# 7             Haryana  IN-HR           HR       Northern
# 8    Himachal Pradesh  IN-HP           HP       Northern
# 9           Jharkhand  IN-JH           JH        Eastern
# 10          Karnataka  IN-KA           KA       Southern
# 11             Kerala  IN-KL           KL       Southern
# 12     Madhya Pradesh  IN-MP           MP        Central
# 13        Maharashtra  IN-MH           MH        Western
# 14            Manipur  IN-MN           MN  North-Eastern
# ...

# %%
df6=df5[4]
df6
# Out:
#                 State    ISO Vehicle code           Zone  \
# 0      Andhra Pradesh  IN-AP           AP       Southern
# 1   Arunachal Pradesh  IN-AR           AR  North-Eastern
# 2               Assam  IN-AS           AS  North-Eastern
# 3               Bihar  IN-BR           BR        Eastern
# 4        Chhattisgarh  IN-CG           CG        Central
# 5                 Goa  IN-GA           GA        Western
# 6             Gujarat  IN-GJ           GJ        Western
# 7             Haryana  IN-HR           HR       Northern
# 8    Himachal Pradesh  IN-HP           HP       Northern
# 9           Jharkhand  IN-JH           JH        Eastern
# 10          Karnataka  IN-KA           KA       Southern
# 11             Kerala  IN-KL           KL       Southern
# 12     Madhya Pradesh  IN-MP           MP        Central
# 13        Maharashtra  IN-MH           MH        Western
# 14            Manipur  IN-MN           MN  North-Eastern
# ...

# %%
dfdf6.iloc[:,0:4]
# Out:
#                 State    ISO Vehicle code           Zone
# 0      Andhra Pradesh  IN-AP           AP       Southern
# 1   Arunachal Pradesh  IN-AR           AR  North-Eastern
# 2               Assam  IN-AS           AS  North-Eastern
# 3               Bihar  IN-BR           BR        Eastern
# 4        Chhattisgarh  IN-CG           CG        Central
# 5                 Goa  IN-GA           GA        Western
# 6             Gujarat  IN-GJ           GJ        Western
# 7             Haryana  IN-HR           HR       Northern
# 8    Himachal Pradesh  IN-HP           HP       Northern
# 9           Jharkhand  IN-JH           JH        Eastern
# 10          Karnataka  IN-KA           KA       Southern
# 11             Kerala  IN-KL           KL       Southern
# 12     Madhya Pradesh  IN-MP           MP        Central
# 13        Maharashtra  IN-MH           MH        Western
# 14            Manipur  IN-MN           MN  North-Eastern
# ...

# %%
df_zone=df5[3]
pd.set_option('display.max_colwidth', 1000) 
df_zone
# Out:
#                          Zone  \
# 0          South Culture Zone
# 1  South Central Culture Zone
# 2          North Culture Zone
# 3  North Central Culture Zone
# 4           East Culture Zone
# 5     North East Culture Zone
# 6           West Culture Zone
#
#                                                    Zonal Centre  \
# 0             South Zone Cultural Centre, Thanjavur, Tamil Nadu
# 1       South-Central Zone Cultural Centre, Nagpur, Maharashtra
# 2                   North Zone Cultural Centre, Patiala, Punjab
# 3  North-Central Zone Cultural Centre, Prayagraj, Uttar Pradesh
# 4               East Zone Cultural Centre, Kolkata, West Bengal
# 5            North East Zone Cultural Centre, Dimapur, Nagaland
# 6                 West Zone Cultural Centre, Udaipur, Rajasthan
#
#                                                                                                               Extent
# ...

# %%
df_zone

# %%
import os
os.getcwd()
# Out:
# '/Users/bkannadasan/Documents/GitHub/DataScience/Python/Wednesday_class'

# %%
import sqlite3

conn = sqlite3.connect('Dataset/file1.db')
df =pd.read_sql_query('select * from emp', conn)
df
# Out:
#    eid    ename
# 0  101     Sree
# 1  102      Sai
# 2  103  Kishore

# %%
from sqlalchemy import create_engine

create_engine?
# Out:
# Signature: create_engine(url: 'Union[str, _url.URL]', **kwargs: 'Any') -> 'Engine'
# Docstring:
# Create a new :class:`_engine.Engine` instance.
#
# The standard calling form is to send the :ref:`URL <database_urls>` as the
# first positional argument, usually a string
# that indicates database dialect and connection arguments::
#
#     engine = create_engine("postgresql+psycopg2://scott:tiger@localhost/test")
#
# .. note::
#
#     Please review :ref:`database_urls` for general guidelines in composing
#     URL strings.  In particular, special characters, such as those often
#     part of passwords, must be URL encoded to be properly parsed.
#
# Additional keyword arguments may then follow it which
# establish various options on the resulting :class:`_engine.Engine`
# and its underlying :class:`.Dialect` and :class:`_pool.Pool`
# constructs::
#
#     engine = create_engine("mysql+mysqldb://scott:tiger@hostname/dbname",
#                                 pool_recycle=3600, echo=True)
# ...

# %%
eng = create_engine('sqlite:///Dataset/file1.db')
df = pd.read_sql_query('select * from emp', eng)

df
# Out:
#    eid    ename
# 0  101     Sree
# 1  102      Sai
# 2  103  Kishore
