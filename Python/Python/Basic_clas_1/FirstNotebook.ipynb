# %%
print ('Hello World')
# Out:
# Hello World

# %%
#This is single line comment -- > #
# Out:
# '\nTHis\nis \nthe \nMultiline\ncomment\n'

# %% [markdown]
# ![image.png](attachment:3eefa9d6-761a-4fad-95a5-1b2f19e39599.png)

# %%
print ('Hello World') this is a print statement # This is not a valid syntax . Hence getting SyntaxError: invalid syntax
# Out:
#   Cell In[5], line 1
#     print ('Hello World') this is a print statement
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## This is the starting of my presentation
#
# - Action points
#     - Follow the clas
#
# This is a CELL
#
# ![image.png](attachment:40c8cbc3-692a-4d0c-b008-189ef8dc610c.png)
# CELL

# %%
# !python --version
# Out:
# Python 3.11.7

# %%
# !ls #- windows dir
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B87F-58CB
#
#  Directory of C:\Users\Balamurugan_Kannadas\Documents\Python Scripts\Day1-26May2024
#
# 01-06-2024  07:57    <DIR>          .
# 01-06-2024  07:27    <DIR>          ..
# 01-06-2024  07:39    <DIR>          .ipynb_checkpoints
# 01-06-2024  07:57           882,289 FirstNotebook.ipynb
#                1 File(s)        882,289 bytes
#                3 Dir(s)  430,448,742,400 bytes free

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !cd
# Out:
# C:\Users\Balamurugan_Kannadas\Documents\Python Scripts\Day1-26May2024

# %%
"""
THis
is 
the 
Multiline
comment
"""
# Out:
# '\nTHis\nis \nthe \nMultiline\ncomment\n'

# %% [markdown]
# ### 1. Keywords, Identifiers & Variable in Python

# %%
# Syntax - System of rules for a Structure definition of a language

# %%
# Keyword - Special words whose functionality was predefined
# EG:
True
False
import
# Out:
#   Cell In[18], line 5
#     import
#           ^
# SyntaxError: invalid syntax

# %%
a = 10
b=20

# %%
True = 20
# Out:
#   Cell In[20], line 1
#     True = 20
#     ^
# SyntaxError: cannot assign to True

# %%
print (a,b)
# Out:
# 10 20

# %%
print (a)
# Out:
# 10

# %% [markdown]
# ### User defined names to nay variable,function,class or any module inside the Notebook is called as an Identifier
#     - Variables are identifiers which holds values that can be changed during the course of program execution
#     - Variables are also Memory holds

# %%
profession = "DataScienctist"
print(profession)
# Out:
# DataScienctist

# %%
20 = 30
# Out:
#   Cell In[25], line 1
#     20 = 30
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ### Rules to follow when you are defining an Identifier in Python
#     1. CANNOT BE KEYWORDS
#     2. CANNOT START WITH NUMBER
#     3. NO SPACE BETWEEN THE VARIABLE NAMES
#     4. NO SPECIAL CHARACTERS = !,@#,$,%
#     5. IT SHOULD START WITH A-Z,a-z,0-9(NOT IN THE START)
#     6. CASE SENSITIVE

# %%
A = 20
a = 20
# A = 20 and a = 20 are different as python is case-sensitive

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a = 10.0
print(type(a))
# Out:
# <class 'float'>

# %%
a = True
print(type(a))
# Out:
# <class 'bool'>

# %%
a = "Bala"
print(type(a))
# Out:
# <class 'str'>

# %%
a = """This
is 
my
first 
class
"""
print(type(a))
# Out:
# <class 'str'>

# %%
a = 1+2j
print(type(a))
# Out:
# <class 'complex'>

# %% [markdown]
# ### Collection of Elements

# %% [markdown]
# #### 1.List
#
#     syntax: ListName = [listelement1, listelement2,...,listelement n]
#     A list stores the elements with respect to its index - Position in which elements are present/stored
#     Zero Based Indexing --> Index number starts with Zero

# %% [markdown]
# ### List Properties
#     Supports Heterogenous collection of data
#     Index starts from 0
#     List elements are mutable via index
#     defined using '[]'

# %%
lst = [0,1,4,56,2]
print(lst)
# Out:
# [0, 1, 4, 56, 2]

# %%
print(type(lst))
# Out:
# <class 'list'>

# %%
print(len(lst))
# Out:
# 5

# %%
lst[3] # Printing the list element based on the index
# Out:
# 56

# %%
lst = [0,1,"Bala",True,1+2j,[0,10,20,30],"Hello world"]

# %%
print(lst)
# Out:
# [0, 1, 'Bala', True, (1+2j), [0, 1, 2, 3], 'Hello world']

# %%
lst[2]
# Out:
# 'Bala'

# %%
lst[5]
# Out:
# [0, 1, 2, 3]

# %%
lst[5][1] ## Print multi-dimension element out of an list here we are printing 1st index element of 5th index element of the list
# Out:
# 10

# %%
print(lst[2])
lst [2]='Bala Murugan'
lst[2]
# Out:
# Bala
# 'Bala Murugan'

# %%
## Difference between '()' and '[]' - When we are using print() - We are accessing the function and giving it an input inside '()'
## But when you want to access the values of a datastructure - Subscriptable entities - We use []

# %% [markdown]
# ## 2. Tuple

# %% [markdown]
# #### Tuple Properties
#     Supports Heterogenous collection of data
#     Index starts from 0
#     Tuple elements are Immutable via index
#     defined using '()'

# %%
tpl = (0,1,2,4)
print(tpl)
# Out:
# (0, 1, 2, 4)

# %%
print(type(tpl))
# Out:
# <class 'tuple'>

# %%
tpl[3]
# Out:
# 4

# %%
tpl[2]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 tpl[2]=1
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### 3.Set

# %% [markdown]
# #### Set Properties
#
# Supports Heterogenous collection of data
# Set elements are Immutable - No index on l    y
# defined using '
#     Numbers are sorted when combined with strings it sometimes sorts{}'

# %%
set = {0,4,11,1,9}
print (set)
# Out:
# {0, 1, 4, 9, 11}

# %%
set = {0,4,11,'a',1,'b',9}
print (set)
# Out:
# {0, 1, 'b', 4, 'a', 11, 9}

# %% [markdown]
# #### 4. Dictionary

# %% [markdown]
# #### Dictionary Properties
#     data is stored as Key value pair
#     Elements are accessed via keys
#     Keys cannot have duplicates
#     Values can be duplicates
#     Values can be mutable via keys
#     Defined using '{KEY:VALUES}'

# %%
dict = {'a':100,'b':200,'c':300,'d':400}

# %%
print(dict)
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'd': 400}

# %%
print(dict['a']);print(dict['d'])
# Out:
# 100
# 400

# %%
dict = {'a':100,'b':200,'c':300,'d':400,'a':500}
print(dict)
# Out:
# {'a': 500, 'b': 200, 'c': 300, 'd': 400}

# %%
dict['a']=600

# %%
dict
# Out:
# {'a': 600, 'b': 200, 'c': 300, 'd': 400}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !ls -lrt
# Out:
# total 1776
# -rw-r--r--  1 bkannadasan  staff  902020 Jun  4 20:56 FirstNotebook.ipynb
# -rw-r--r--  1 bkannadasan  staff      22 Jun  4 20:56 hello.py

# %%
# !pwd
# Out:
# /Users/bkannadasan/Documents/GitHub/DataScience/Python/Day1-26May2024
