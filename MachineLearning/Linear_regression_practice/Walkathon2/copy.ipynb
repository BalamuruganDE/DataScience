# %%
# import libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()

# %%
#Loading the dataset
df=pd.read_csv('data.csv')

# %%
#finding the length dataset
df.shape

# %%
#columns of dataset
df.columns

# %%
df.info()

# %%
#show few records
df.head()

# %%
#show unique count of vaules in the each column
df.nunique()

# %%
sns.countplot(data=df,y=df['CONSOLE'])

# %%
sns.countplot(data=df,x=df['CONSOLE'])

# %%
for col in df.select_dtypes(include='object').columns:
    sns.countplot(data=df,x=col)
    plt.xticks(rotation=90)
    plt.show()

# %%
# !python --version

# %%
sys.version

# %%
df.describe()

# %%
df['YEAR'].value_counts().sort_index()

# %%
for col in df.drop(columns=['ID']).select_dtypes(exclude='object').columns:
    sns.histplot(data=df,x=col)

    # plt.xticks(rotation=90)
    plt.show()

# %%
sns.heatmap(df.drop(columns=['ID']).select_dtypes(exclude='object').corr(),annot=True)

# %%
sns.pairplot(df)

# %%
target_col = 'SalesInMillions'
target_col

# %%
cat_cols = df.select_dtypes(include='object').columns
cat_cols

# %%
num_cols = df.select_dtypes(exclude='object').columns
num_cols

# %%
ignore_col = 'ID'
ignore_col

# %%
num_cols = df.drop(columns=ignore_col).select_dtypes(exclude='object').columns
num_cols

# %%
df.info()

# %%
df.nunique()

# %%
Allowed_max_uniq_size=25
uniq_cols_to_encode=[]
for col in df.columns:
    ulen=df[col].nunique()
    # print(col,'=',df[col].unique())
    if ulen <=Allowed_max_uniq_size:
        uniq_cols_to_encode.append(col)
        print(col,df[col].dtypes)

uniq_cols_to_encode

# %%
uniq_cols_to_encode.append('PUBLISHER')
uniq_cols_to_encode

# %%
# %%
# import libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys

import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()

# %%
#Loading the dataset
df=pd.read_csv('data.csv')

# %%
#finding the length dataset
df.shape

# %%
#columns of dataset
df.columns

# %%
df.info()

# %%
#show few records
df.head()

# %%
#show unique count of vaules in the each column
df.nunique()

# %%
sns.countplot(data=df,y=df['CONSOLE'])

# %%
sns.countplot(data=df,x=df['CONSOLE'])

# %%
for col in df.select_dtypes(include='object').columns:
    sns.countplot(data=df,x=col)
    plt.xticks(rotation=90)
    plt.show()

# %%
# !python --version

# %%
sys.version

# %%
df.describe()

# %%
df['YEAR'].value_counts().sort_index()

# %%
for col in df.drop(columns=['ID']).select_dtypes(exclude='object').columns:
    sns.histplot(data=df,x=col)

    # plt.xticks(rotation=90)
    plt.show()

# %%
sns.heatmap(df.drop(columns=['ID']).select_dtypes(exclude='object').corr(),annot=True)

# %%
sns.pairplot(df)

# %%
target_col = 'SalesInMillions'
target_col

# %%
cat_cols = df.select_dtypes(include='object').columns
cat_cols

# %%
num_cols = df.select_dtypes(exclude='object').columns
num_cols

# %%
ignore_col = 'ID'
ignore_col

# %%
num_cols = df.drop(columns=ignore_col).select_dtypes(exclude='object').columns
num_cols

# %%
df.info()

# %%
df.nunique()

# %%
Allowed_max_uniq_size=25
uniq_cols_to_encode=[]
for col in df.columns:
    ulen=df[col].nunique()
    # print(col,'=',df[col].unique())
    if ulen <=Allowed_max_uniq_size:
        uniq_cols_to_encode.append(col)
        print(col,df[col].dtypes)

uniq_cols_to_encode

# %%
uniq_cols_to_encode.append('PUBLISHER')
uniq_cols_to_encode

# %%


# %%


# %%


# %%


# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3506 entries, 0 to 3505
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               3506 non-null   int64
#  1   CONSOLE          3506 non-null   object
#  2   YEAR             3506 non-null   int64
#  3   CATEGORY         3506 non-null   object
#  4   PUBLISHER        3506 non-null   object
#  5   RATING           3506 non-null   object
#  6   CRITICS_POINTS   3506 non-null   float64
#  7   USER_POINTS      3506 non-null   float64
#  8   SalesInMillions  3506 non-null   float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 246.6+ KB
# Python 3.12.4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3506 entries, 0 to 3505
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               3506 non-null   int64
# ...

# %%
# import libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

os.getcwd()

#Loading the dataset
df=pd.read_csv('data.csv')

#finding the length dataset
df.shape

#columns of dataset
df.columns

df.info()
