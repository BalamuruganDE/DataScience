# %%
	
import numpy as np

# Define the data points
X = np.array([[1, 1],  # x = 1
              [1, 2],  # x = 2
              [1, 3]]) # x = 3
y = np.array([2, 3, 5])  # Corresponding y values

# %%
print(X,'\n',y)
# Out:
# [[1 1]
#  [1 2]
#  [1 3]]
#  [2 3 5]

# %%
X[:,1]
# Out:
# array([1, 2, 3])

# %%
X_=X[:,1]

# %%
n=len(y)
n
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
iteration=5
learning_rate = 0.01
m = 0
b = 0
error_list=[]
error=0
for i in range(iteration):
    print("Input:",X_)
    print("(-) of X_:",-X_)
    y_pred = m*X_+b
    print("Initial m:",m,"--- Initial b:",b)
    print("Predicated y (y^):",y_pred)
    print("Actual y (y):",y)
    error=y-y_pred
    old_error = error_sum
    print("Error:",error)
    error_sum=np.sum(error)
    print("error_sum:",error_sum)
    error_list.append(error_sum)
    m_gradient=(1/n)*np.dot((error),-X_)
    print("m_gradient:",m_gradient)
    m = m-(m_gradient*learning_rate)
    print("new slope point:",m)
    print("old_error:",old_error)
    change = abs(error_sum - old_error)
    print("change:",change)
    if change < 0.001:
        break

print ("Length of error_list:",len(error_list))
print("error_list:",error_list)
# Out:
# Input: [1 2 3]
# (-) of X_: [-1 -2 -3]
# Initial m: 0 --- Initial b: 0
# Predicated y (y^): [0 0 0]
# Actual y (y): [2 3 5]
# Error: [2 3 5]
# error_sum: 10
# m_gradient: -7.666666666666666
# new slope point: 0.07666666666666666
# old_error: 8.28483963851852
# change: 1.7151603614814803
# Input: [1 2 3]
# (-) of X_: [-1 -2 -3]
# Initial m: 0.07666666666666666 --- Initial b: 0
# Predicated y (y^): [0.07666667 0.15333333 0.23      ]
# Actual y (y): [2 3 5]
# Error: [1.92333333 2.84666667 4.77      ]
# error_sum: 9.54
# m_gradient: -7.308888888888888
# new slope point: 0.14975555555555553
# old_error: 10
# change: 0.46000000000000085
# Input: [1 2 3]
# (-) of X_: [-1 -2 -3]
# Initial m: 0.14975555555555553 --- Initial b: 0
# Predicated y (y^): [0.14975556 0.29951111 0.44926667]
# Actual y (y): [2 3 5]
# Error: [1.85024444 2.70048889 4.55073333]
# error_sum: 9.101466666666667
# m_gradient: -6.967807407407407
# new slope point: 0.2194336296296296
# old_error: 9.54
# ...

# %%
iteration=10000
learning_rate = 0.01
m = 0
b = 0
error_list=[]
error=0
for i in range(iteration):
    # print("Input:",X_)
    # print("(-) of X_:",-X_)
    y_pred = m*X_+b
    # print("Initial m:",m,"--- Initial b:",b)
    # print("Predicated y (y^):",y_pred)
    # print("Actual y (y):",y)
    error=y-y_pred
    old_error = error_sum
    # print("Error:",error)
    error_sum=np.sum(error)
    # print("error_sum:",error_sum)
    error_list.append(error_sum)
    m_gradient=(1/n)*np.dot((error),-X_)
    # print("m_gradient:",m_gradient)
    m = m-(m_gradient*learning_rate)
    # print("new slope point:",m)
    # print("old_error:",old_error)
    change = abs(error_sum - old_error)
    # print("change:",change)
    # if change < 0.0001:
    if i >1000:
        print('iteration:',i,'   change:',change)
        break

print ("Length of error_list:",len(error_list))
print("Min of error_list:",min(error_list))
# Out:
# iteration: 1001    change: 0.0
# Length of error_list: 1002
# Min of error_list: 0.14285714285715656

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(error_list)

# %%
(-2/n)*np.sum(error)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 (-2/n)*np.sum(error)
#
# NameError: name 'error' is not defined
